# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
rewards = np.load('test/noprio_rewards.npy')
nopriov2 = np.load('test/nopriov2_rewards.npy')
nopriov3 = np.load('test/nopriov3_rewards.npy')
duelv1 = np.load('test/duelv1_rewards.npy')
v1 = np.load('test/v1_rewards.npy')
v2 = np.load('test/v2_rewards.npy')

fig, axs = plt.subplots(6,1, figsize=(10,10))
axs[2].plot(rewards)
axs[0].plot(v1)
axs[1].plot(v2)
axs[3].plot(nopriov2)
axs[4].plot(nopriov3)
axs[5].plot(duelv1)
print(v1.mean())
print(v2.mean())
print(rewards.mean())
print(nopriov2.mean())
print(nopriov3.mean())
print(duelv1.mean())
# Out:
# 13.56
# 14.18
# 32.01
# 13.61
# 33.43
# 27.26

# %%
noprio = np.load('results/noprio/reward.npy')
duel = np.load('results/duelv1/reward.npy')

# %%
print(noprio.shape)
print(duel.shape)
# Out:
# (22279,)
# (16079,)
